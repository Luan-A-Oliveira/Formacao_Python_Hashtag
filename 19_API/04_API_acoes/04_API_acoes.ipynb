# %% [markdown]
# ### Alpha Vantage
#
# https://www.alphavantage.co/documentation/

# %% [markdown]
# #### Pegando cotações semanais - JSON

# %%
from chave import chave_api

import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY_ADJUSTED&symbol=ITUB4.SAO&apikey={chave_api}'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Weekly Adjusted Prices and Volumes', '2. Symbol': 'ITUB4.SAO', '3. Last Refreshed': '2023-10-27', '4. Time Zone': 'US/Eastern'}, 'Weekly Adjusted Time Series': {'2023-10-27': {'1. open': '26.9000', '2. high': '27.9000', '3. low': '26.8200', '4. close': '27.3000', '5. adjusted close': '27.3000', '6. volume': '116410500', '7. dividend amount': '0.0000'}, '2023-10-20': {'1. open': '27.8800', '2. high': '27.9000', '3. low': '26.5800', '4. close': '26.9600', '5. adjusted close': '26.9600', '6. volume': '141131700', '7. dividend amount': '0.0000'}, '2023-10-13': {'1. open': '27.6500', '2. high': '28.0900', '3. low': '27.4000', '4. close': '27.6900', '5. adjusted close': '27.6900', '6. volume': '77340100', '7. dividend amount': '0.0000'}, '2023-10-06': {'1. open': '27.1400', '2. high': '28.2900', '3. low': '26.5500', '4. close': '27.9000', '5. adjusted close': '27.9000', '6. volume': '130553100', '7. dividend amount': '0.0000'}, '2023-09-29': {'1. open': '26.9400', '2. high': '27.5700', '3. low': '26.3600', '4. close': '27.2100', '5. adjusted close': '27.2100', '6. volume': '107695400', '7. dividend amount': '0.0176'}, '2023-09-22': {'1. open': '27.6500', '2. high': '27.8400', '3. low': '26.8900', '4. close': '26.9200', '5. adjusted close': '26.9026', '6. volume': '96648500', '7. dividend amount': '0.2693'}, '2023-09-15': {'1. open': '27.0000', '2. high': '28.0400', '3. low': '26.8900', '4. close': '27.5800', '5. adjusted close': '27.2930', '6. volume': '133419800', '7. dividend amount': '0.0000'}, '2023-09-08': {'1. open': '27.5300', '2. high': '27.7100', '3. low': '26.5300', '4. close': '26.7700', '5. adjusted close': '26.4914', '6. volume': '72465200', '7. dividend amount': '0.0000'}, '2023-09-01': {'1. open': '26.8800', '2. high': '28.5900', '3. low': '26.7200', '4. close': '27.6500', '5. adjusted close': '27.3623', '6. volume': '153588600', '7. dividend amount': '0.0176'}, '2023-08-25': {'1. open': '26.8600', '2. high': '27.7200', '3. low': '26.6700', '4. close': '26.8600', '5. adjusted close': '26.5635', '6. volume': '119168400', '7. dividend amount': '0.0000'}, '2023-08-18': {'1. open': '27.4800', '2. high': '27.6200', '3. low': '26.5400', '4. close': '26.9600', '5. adjusted close': '26.6624', '6. volume': '142773500', '7. dividend amount': '0.0000'}, '2023-08-11': {'1. open': '27.9300', '2. high': '28.2800', '3. low': '26.9200', '4. close': '27.6400', '5. adjusted close': '27.3349', '6. volume': '162625600', '7. dividend amount': '0.0000'}, '2023-08-04': {'1. open': '28.7900', '2. high': '29.1300', '3. low': '27.7000', '4. close': '27.8800', '5. adjusted close': '27.5723', '6. volume': '114535800', '7. dividend amount': '0.0176'}, '2023-07-28': {'1. open': '29.0000', '2. high': '29.2500', '3. low': '28.0600', '4. close': '28.5400', '5. adjusted close': '28.2076', '6. volume': '137194700', '7. dividend amount': '0.0000'}, '2023-07-21': {'1. open': '28.2300', '2. high': '29.0000', '3. low': '27.7000', '4. close': '29.0000', '5. adjusted close': '28.6622', '6. volume': '164082300', '7. dividend amount': '0.0000'}, '2023-07-14': {'1. open': '29.3700', '2. high': '29.3700', '3. low': '28.1000', '4. close': '28.2800', '5. adjusted close': '27.9506', '6. volume': '106228800', '7. dividend amount': '0.0000'}, '2023-07-07': {'1. open': '28.5400', '2. high': '29.4600', '3. low': '28.3600', '4. close': '29.1400', '5. adjusted close': '28.8006', '6. volume': '99545900', '7. dividend amount': '0.0000'}, '2023-06-30': {'1. open': '28.6300', '2. high': '28.9400', '3. low': '27.9800', '4. close': '28.4200', '5. adjusted close': '28.0889', '6. volume': '148091200', '7. dividend amount': '0.0176'}, '2023-06-23': {'1. open': '28.5800', '2. high': '29.1700', '3. low': '28.3600', '4. close': '28.6700', '5. adjusted close': '28.3185', '6. volume': '107952100', '7. dividend amount': '0.2663'}, '2023-06-16': {'1. open': '27.9300', '2. high': '28.8400', '3. low': '27.4200', '4. close': '28.6500', '5. adjusted close': ...

# %% [markdown]
# #### Pegando cotações semanais - CSV

# %%
import pandas as pd
from io import StringIO

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY_ADJUSTED&symbol=ITUB4.SAO&apikey={chave_api}&datatype=csv'
r = requests.get(url)

tabela = pd.read_csv(StringIO(r.text))
display(tabela)
# Out:
#       timestamp      open      high       low     close  adjusted close  \
# 0    2023-10-27   26.9000   27.9000   26.8200   27.3000         27.3000
# 1    2023-10-20   27.8800   27.9000   26.5800   26.9600         26.9600
# 2    2023-10-13   27.6500   28.0900   27.4000   27.6900         27.6900
# 3    2023-10-06   27.1400   28.2900   26.5500   27.9000         27.9000
# 4    2023-09-29   26.9400   27.5700   26.3600   27.2100         27.2100
# ..          ...       ...       ...       ...       ...             ...
# 984  2005-02-11  430.0002  438.0024  426.9987  432.8991          3.2211
# 985  2005-02-04  384.4994  440.0015  384.4994  438.0024          3.2591
# 986  2005-01-28  386.9996  392.0003  375.5004  378.9974          2.8190
# 987  2005-01-21  397.9007  402.9920  386.0997  389.5001          2.8972
# 988  2005-01-14  390.0074  398.0096  383.9981  398.0096          2.9605
#
#         volume  dividend amount
# 0    116410500           0.0000
# 1    141131700           0.0000
# 2     77340100           0.0000
# 3    130553100           0.0000
# 4    107695400           0.0176
# ..         ...              ...
# 984  637399594           0.0000
# 985  894557778           0.0024
# 986  864360715           0.0000
# 987  847329571           0.0000
# 988  942510713           0.0000
#
# [989 rows x 8 columns]

# %% [markdown]
# ### Cotações

# %%
acoes = ['ITUB4', 'ABEV3', 'BBAS3']

compilada = pd.DataFrame()

for acao in acoes:
    url = f'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol={acao}.SAO&apikey={chave_api}&datatype=csv'
    r = requests.get(url)
    tabela = pd.read_csv(StringIO(r.text))
    lista_tabelas = [compilada, tabela]
    compilada = pd.concat(lista_tabelas)
    
display(compilada)
# Out:
#       symbol   open   high    low  price    volume   latestDay  previousClose  \
# 0  ITUB4.SAO  27.84  27.90  27.19  27.30  30176000  2023-10-27          27.71
# 0  ABEV3.SAO  12.58  12.63  12.28  12.29  27730300  2023-10-27          12.63
# 0  BBAS3.SAO  49.90  50.06  48.53  48.80  10168900  2023-10-27          50.07
#
#    change changePercent
# 0   -0.41      -1.4796%
# 0   -0.34      -2.6920%
# 0   -1.27      -2.5364%

# %% [markdown]
# ### Encontrar ativos

# %%
url = f'https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords=amazon&apikey={chave_api}&datatype=csv'
r = requests.get(url)

tabela = pd.read_csv(StringIO(r.text))
display(tabela)
# Out:
#        symbol                      name    type            region marketOpen  \
# 0        AMZN            Amazon.com Inc  Equity     United States      09:30
# 1     AMZ.DEX            Amazon.com Inc  Equity             XETRA      08:00
# 2     AMZ.FRK            Amazon.com Inc  Equity         Frankfurt      08:00
# 3  AMZO34.SAO            Amazon.com Inc  Equity  Brazil/Sao Paolo      10:00
# 4    0R1O.LON           Amazon.com Inc.  Equity    United Kingdom      08:00
# 5    AMZ1.FRK  AMAZON.COM INC.CDR DL-01  Equity         Frankfurt      08:00
# 6        AZFL    Amazonas Florestal Ltd  Equity     United States      09:30
#
#   marketClose timezone currency  matchScore
# 0       16:00   UTC-04      USD      0.8000
# 1       20:00   UTC+02      EUR      0.6000
# 2       20:00   UTC+02      EUR      0.6000
# 3       17:30   UTC-03      BRL      0.6000
# 4       16:30   UTC+01      USD      0.5714
# 5       20:00   UTC+02      EUR      0.5000
# 6       16:00   UTC-04      USD      0.4286

# %% [markdown]
# ### Informações de Resultado

# %%
url = f'https://www.alphavantage.co/query?function=EARNINGS&symbol=AMZN&apikey={chave_api}'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'symbol': 'AMZN', 'annualEarnings': [{'fiscalDateEnding': '2023-09-30', 'reportedEPS': '1.9'}, {'fiscalDateEnding': '2022-12-31', 'reportedEPS': '0.97'}, {'fiscalDateEnding': '2021-12-31', 'reportedEPS': '2.15'}, {'fiscalDateEnding': '2020-12-31', 'reportedEPS': '2.09'}, {'fiscalDateEnding': '2019-12-31', 'reportedEPS': '1.14'}, {'fiscalDateEnding': '2018-12-31', 'reportedEPS': '1'}, {'fiscalDateEnding': '2017-12-31', 'reportedEPS': '0.23'}, {'fiscalDateEnding': '2016-12-31', 'reportedEPS': '0.25'}, {'fiscalDateEnding': '2015-12-31', 'reportedEPS': '0.06'}, {'fiscalDateEnding': '2014-12-31', 'reportedEPS': '-0.03'}, {'fiscalDateEnding': '2013-12-31', 'reportedEPS': '-0.07'}, {'fiscalDateEnding': '2012-12-31', 'reportedEPS': '0.02'}, {'fiscalDateEnding': '2011-12-31', 'reportedEPS': '0.07'}, {'fiscalDateEnding': '2010-12-31', 'reportedEPS': '0.13'}, {'fiscalDateEnding': '2009-12-31', 'reportedEPS': '0.1'}, {'fiscalDateEnding': '2008-12-31', 'reportedEPS': '0.08'}, {'fiscalDateEnding': '2007-12-31', 'reportedEPS': '0.05'}, {'fiscalDateEnding': '2006-12-31', 'reportedEPS': '0.12'}, {'fiscalDateEnding': '2005-12-31', 'reportedEPS': '0.11'}, {'fiscalDateEnding': '2004-12-31', 'reportedEPS': '0.05'}, {'fiscalDateEnding': '2003-12-31', 'reportedEPS': '0.04'}, {'fiscalDateEnding': '2002-12-31', 'reportedEPS': '-0.1024'}, {'fiscalDateEnding': '2001-12-31', 'reportedEPS': '0.06'}, {'fiscalDateEnding': '2000-12-31', 'reportedEPS': '-0.06'}, {'fiscalDateEnding': '1999-12-31', 'reportedEPS': '-0.06'}, {'fiscalDateEnding': '1998-12-31', 'reportedEPS': '-0.25'}, {'fiscalDateEnding': '1997-12-31', 'reportedEPS': '-0.08'}], 'quarterlyEarnings': [{'fiscalDateEnding': '2023-09-30', 'reportedDate': '2023-10-26', 'reportedEPS': '0.94', 'estimatedEPS': '0.58', 'surprise': '0.36', 'surprisePercentage': '62.069'}, {'fiscalDateEnding': '2023-06-30', 'reportedDate': '2023-08-03', 'reportedEPS': '0.65', 'estimatedEPS': '0.35', 'surprise': '0.3', 'surprisePercentage': '85.7143'}, {'fiscalDateEnding': '2023-03-31', 'reportedDate': '2023-04-27', 'reportedEPS': '0.31', 'estimatedEPS': '0.21', 'surprise': '0.1', 'surprisePercentage': '47.619'}, {'fiscalDateEnding': '2022-12-31', 'reportedDate': '2023-02-02', 'reportedEPS': '0.25', 'estimatedEPS': '0.18', 'surprise': '0.07', 'surprisePercentage': '38.8889'}, {'fiscalDateEnding': '2022-09-30', 'reportedDate': '2022-10-27', 'reportedEPS': '0.17', 'estimatedEPS': '0.22', 'surprise': '-0.05', 'surprisePercentage': '-22.7273'}, {'fiscalDateEnding': '2022-06-30', 'reportedDate': '2022-07-28', 'reportedEPS': '0.18', 'estimatedEPS': '0.14', 'surprise': '0.04', 'surprisePercentage': '28.5714'}, {'fiscalDateEnding': '2022-03-31', 'reportedDate': '2022-04-28', 'reportedEPS': '0.37', 'estimatedEPS': '0.42', 'surprise': '-0.05', 'surprisePercentage': '-11.9048'}, {'fiscalDateEnding': '2021-12-31', 'reportedDate': '2022-02-03', 'reportedEPS': '0.29', 'estimatedEPS': '0.18', 'surprise': '0.11', 'surprisePercentage': '61.1111'}, {'fiscalDateEnding': '2021-09-30', 'reportedDate': '2021-10-28', 'reportedEPS': '0.31', 'estimatedEPS': '0.45', 'surprise': '-0.14', 'surprisePercentage': '-31.1111'}, {'fiscalDateEnding': '2021-06-30', 'reportedDate': '2021-07-29', 'reportedEPS': '0.76', 'estimatedEPS': '0.62', 'surprise': '0.14', 'surprisePercentage': '22.5806'}, {'fiscalDateEnding': '2021-03-31', 'reportedDate': '2021-04-29', 'reportedEPS': '0.79', 'estimatedEPS': '0.48', 'surprise': '0.31', 'surprisePercentage': '64.5833'}, {'fiscalDateEnding': '2020-12-31', 'reportedDate': '2021-02-02', 'reportedEPS': '0.7', 'estimatedEPS': '0.36', 'surprise': '0.34', 'surprisePercentage': '94.4444'}, {'fiscalDateEnding': '2020-09-30', 'reportedDate': '2020-10-29', 'reportedEPS': '0.62', 'estimatedEPS': '0.37', 'surprise': '0.25', 'surprisePercentage': '67.5676'}, {'fiscalDateEnding': '2020-06-30', 'reportedDate': '2020-07-30', 'reportedEPS': '0.52', 'estimatedEPS': '0.07', 'surprise': '0.45', 'surprisePercentage': '642.8571'}, {'fiscalDateEndi ...

# %%
import pprint

#pprint.pprint(data)

resultado = pd.DataFrame(data['annualEarnings'])
display(resultado)
# Out:
#    fiscalDateEnding reportedEPS
# 0        2023-09-30         1.9
# 1        2022-12-31        0.97
# 2        2021-12-31        2.15
# 3        2020-12-31        2.09
# 4        2019-12-31        1.14
# 5        2018-12-31           1
# 6        2017-12-31        0.23
# 7        2016-12-31        0.25
# 8        2015-12-31        0.06
# 9        2014-12-31       -0.03
# 10       2013-12-31       -0.07
# 11       2012-12-31        0.02
# 12       2011-12-31        0.07
# 13       2010-12-31        0.13
# 14       2009-12-31         0.1
# 15       2008-12-31        0.08
# 16       2007-12-31        0.05
# 17       2006-12-31        0.12
# 18       2005-12-31        0.11
# 19       2004-12-31        0.05
# 20       2003-12-31        0.04
# 21       2002-12-31     -0.1024
# 22       2001-12-31        0.06
# 23       2000-12-31       -0.06
# 24       1999-12-31       -0.06
# 25       1998-12-31       -0.25
# 26       1997-12-31       -0.08
